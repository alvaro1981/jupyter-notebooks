# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
iris = sns.load_dataset("iris")
print(type(iris))
iris
# Out:
# <class 'pandas.core.frame.DataFrame'>
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.sample(5, random_state = 0)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 114           5.8          2.8           5.1          2.4   virginica
# 62            6.0          2.2           4.0          1.0  versicolor
# 33            5.5          4.2           1.4          0.2      setosa
# 107           7.3          2.9           6.3          1.8   virginica
# 7             5.0          3.4           1.5          0.2      setosa

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris["label"] = iris.species.astype("category").cat.codes

# %%
iris.sample(5, random_state = 0)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species  label
# 114           5.8          2.8           5.1          2.4   virginica      2
# 62            6.0          2.2           4.0          1.0  versicolor      1
# 33            5.5          4.2           1.4          0.2      setosa      0
# 107           7.3          2.9           6.3          1.8   virginica      2
# 7             5.0          3.4           1.5          0.2      setosa      0

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  label
# 0           5.1          3.5           1.4          0.2  setosa      0
# 1           4.9          3.0           1.4          0.2  setosa      0
# 2           4.7          3.2           1.3          0.2  setosa      0
# 3           4.6          3.1           1.5          0.2  setosa      0
# 4           5.0          3.6           1.4          0.2  setosa      0

# %%
# vamos a visualizar la relacion que hay entre la longitud y el ancho de los sepalos llevando ambas
# caracteristicas a un diagrama de 
fig, ax = plt.subplots(figsize = (7, 7))
ax.set_aspect("equal")
LstedColormap = ["#E67332", "#FADB15", "#4193E5"]
scatter = ax.scatter(
    x = iris["sepal_length"], y = iris["sepal_width"],
    c = iris.label, zorder = 2, edgecolor = "#999999",
)
ax.set_title("Sepal length vs Sepal width")
ax.set_xlabel("Sepal length (cm)")
ax.set_ylabel("Sepal width (cm) ")
ax.legend(
    handles = scatter.legend_elements()[0],
    labels = list(iris.species.unique())
)
ax.grid(color = "#EEEEEE", zorder = 1, alpha = 0.9)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
